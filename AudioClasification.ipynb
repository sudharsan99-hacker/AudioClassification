# %%
# !pip install numpy==1.26.4
import librosa
import librosa.display
import numpy as np
import os
import matplotlib.pyplot as plt
# Out:
# ...
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
np.float = float
np.complex = complex

def create_spectrogram(audio_file, image_file):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1)

    y, sr = librosa.load(audio_file)
    ms = librosa.feature.melspectrogram(y=y, sr=sr)
    log_ms = librosa.power_to_db(ms, ref=np.max)
    librosa.display.specshow(log_ms, sr=sr)

    fig.savefig(image_file)
    plt.close(fig)

def create_pngs_from_wavs(input_path, output_path):
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    dir = os.listdir(input_path)

    for i, file in enumerate(dir):
        input_file = os.path.join(input_path, file)
        output_file = os.path.join(output_path, file.replace('.wav', '.png'))
        create_spectrogram(input_file, output_file)

# %%
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Band-tailed_Guan_sound", "/content/drive/MyDrive/Spectograms/Band-tailed_Guan_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Darwins_Nothura_sound", "/content/drive/MyDrive/Spectograms/Darwins_Nothura_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/East_Brazilian_Chachalaca_sound", "/content/drive/MyDrive/Spectograms/East_Brazilian_Chachalaca_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Greater_Rhea_sound", "/content/drive/MyDrive/Spectograms/Greater_Rhea_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Lesser_Nothura_sound", "/content/drive/MyDrive/Spectograms/Lesser_Nothura_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Maleo_sound", "/content/drive/MyDrive/Spectograms/Maleo_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/New_Guinea_Scrubfowl_sound", "/content/drive/MyDrive/Spectograms/New_Guinea_Scrubfowl_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Okarito_Kiwi_sound", "/content/drive/MyDrive/Spectograms/Okarito_Kiwi_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Pale-browed_Tinamou_sound", "/content/drive/MyDrive/Spectograms/Pale-browed_Tinamou_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Quebracho_Crested_Tinamou_sound", "/content/drive/MyDrive/Spectograms/Quebracho_Crested_Tinamou_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Red-billed_Brushturkey_sound", "/content/drive/MyDrive/Spectograms/Red-billed_Brushturkey_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Scaled_Chachalaca_sound", "/content/drive/MyDrive/Spectograms/Scaled_Chachalaca_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Taczanowskis_Tinamou_sound", "/content/drive/MyDrive/Spectograms/Taczanowskis_Tinamou_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Undulated_Tinamou_sound", "/content/drive/MyDrive/Spectograms/Undulated_Tinamou_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Vanuatu_Megapode_sound", "/content/drive/MyDrive/Spectograms/Vanuatu_Megapode_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Wattled_Brushturkey_sound", "/content/drive/MyDrive/Spectograms/Wattled_Brushturkey_sound")
create_pngs_from_wavs("/content/drive/MyDrive/Sounds/Yellow-legged_Tinamou_sound", "/content/drive/MyDrive/Spectograms/Yellow-legged_Tinamou_sound")

# %%
from tensorflow.keras.preprocessing import image

def load_images_from_path(path, label):
    images = []
    labels = []

    for file in os.listdir(path):
        images.append(image.img_to_array(image.load_img(os.path.join(path, file), target_size=(224, 224, 3))))
        labels.append((label))

    return images, labels

def show_images(images):
    fig, axes = plt.subplots(1, 8, figsize=(20, 20), subplot_kw={'xticks': [], 'yticks': []})

    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i] / 255)

x = []
y = []
i = 0

# %%
lis = ["/content/drive/MyDrive/Spectograms/Band-tailed_Guan_sound",
"/content/drive/MyDrive/Spectograms/Darwins_Nothura_sound",
"/content/drive/MyDrive/Spectograms/East_Brazilian_Chachalaca_sound",
"/content/drive/MyDrive/Spectograms/Greater_Rhea_sound",
"/content/drive/MyDrive/Spectograms/Lesser_Nothura_sound",
"/content/drive/MyDrive/Spectograms/Maleo_sound",
"/content/drive/MyDrive/Spectograms/New_Guinea_Scrubfowl_sound",
"/content/drive/MyDrive/Spectograms/Okarito_Kiwi_sound",
"/content/drive/MyDrive/Spectograms/Pale-browed_Tinamou_sound",
"/content/drive/MyDrive/Spectograms/Quebracho_Crested_Tinamou_sound",
"/content/drive/MyDrive/Spectograms/Red-billed_Brushturkey_sound",
"/content/drive/MyDrive/Spectograms/Scaled_Chachalaca_sound",
"/content/drive/MyDrive/Spectograms/Taczanowskis_Tinamou_sound",
"/content/drive/MyDrive/Spectograms/Undulated_Tinamou_sound",
"/content/drive/MyDrive/Spectograms/Vanuatu_Megapode_sound",
"/content/drive/MyDrive/Spectograms/Wattled_Brushturkey_sound",
"/content/drive/MyDrive/Spectograms/Yellow-legged_Tinamou_sound"]

# %%
for j in lis:
    images, labels = load_images_from_path(j, i)
    # show_images(images)
    i += 1
    x += images
    y += labels

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.3, random_state=0)

x_train_norm = np.array(x_train) / 255
x_test_norm = np.array(x_test) / 255

y_train_encoded = to_categorical(y_train)
y_test_encoded = to_categorical(y_test)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Flatten, Dense

# %%
model = Sequential()
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(17, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ...

# %%
hist = model.fit(x_train_norm, y_train_encoded, validation_data=(x_test_norm, y_test_encoded), batch_size=10, epochs=10)
model.save("audio.keras")
# Out:
# Epoch 1/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.1418 - loss: 2.7706 - val_accuracy: 0.2532 - val_loss: 2.4808
# Epoch 2/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.3178 - loss: 2.2223 - val_accuracy: 0.2405 - val_loss: 2.3959
# Epoch 3/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 74s 2s/step - accuracy: 0.4116 - loss: 1.9402 - val_accuracy: 0.2911 - val_loss: 2.5084
# Epoch 4/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.5045 - loss: 1.6049 - val_accuracy: 0.6203 - val_loss: 1.4756
# Epoch 5/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.7930 - loss: 0.9450 - val_accuracy: 0.7595 - val_loss: 1.1614
# Epoch 6/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.8241 - loss: 0.6904 - val_accuracy: 0.7089 - val_loss: 1.1368
# Epoch 7/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8705 - loss: 0.4922 - val_accuracy: 0.7089 - val_loss: 1.1515
# Epoch 8/10
# ...

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []
